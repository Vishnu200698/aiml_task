# %%
import pandas as pd
import numpy as np

# %%
data=[10,20,30,40.7]
series=pd.Series(data)
print(series)
print(series.dtype)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.7
# dtype: float64
# float64

# %%
data=[1,2,3,4]
i=['a','b','c','d']
series=pd.Series(data,index=i)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data={'a':10,'b':20,'c':30}
series=pd.Series(data)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
series.replace(10,100)
# Out:
# a    100
# b     20
# c     30
# dtype: int64

# %%
import pandas as pd
data={'Name':['Alice','bob','mary','john'], 'Age':[25,30,40,50], 'Country':['USA','INDIA','UK','AUS']}

df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age Country
# 0  Alice   25     USA
# 1    bob   30   INDIA
# 2   mary   40      UK
# 3   john   50     AUS

# %%
import pandas as pd
data={'Name':['Alice','bob','mary','john'], 'Age':[25,30,40,50], 'Country':['USA','INDIA','UK','AUS']}
i=['a','b','c','d']
df=pd.DataFrame(data,index=i)
print(df)
# Out:
#     Name  Age Country
# a  Alice   25     USA
# b    bob   30   INDIA
# c   mary   40      UK
# d   john   50     AUS

# %%
import pandas as pd
data={'Name':['Alice','bob','mary','john','vishnu','nishanth','gopi'], 'Age':[25,30,40,50,25,80,70], 'Country':['USA','INDIA','UK','AUS','INDIA','INDIA','INDIA'], 'CGPA':[7,8,5,6,7,'infinity',8]}
i=['a','b','c','d','e','g','y']
df=pd.DataFrame(data,index=i)
print(df)
# Out:
#        Name  Age Country      CGPA
# a     Alice   25     USA         7
# b       bob   30   INDIA         8
# c      mary   40      UK         5
# d      john   50     AUS         6
# e    vishnu   25   INDIA         7
# g  nishanth   80   INDIA  infinity
# y      gopi   70   INDIA         8

# %%
import numpy as np
array=np.array([[1,20,30],[1,2,3],[3,4,5]])
print(array)
df=pd.DataFrame(array, columns=['c1','c2','c3'] ,index=['a','b','c'])
print(df)
# Out:
# [[ 1 20 30]
#  [ 1  2  3]
#  [ 3  4  5]]
#    c1  c2  c3
# a   1  20  30
# b   1   2   3
# c   3   4   5

# %%
import pandas as pd
iris=pd.read_csv('iris.csv')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.shape)
print(iris.ndim)
print(iris.size)
# Out:
# (150, 5)
# 2
# 750

# %%
import numpy as np
iris_array=np.array(iris)
iris_array
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
iris[["sepal_length", "petal_width"]]
# Out:
#      sepal_length  petal_width
# 0             5.1          0.2
# 1             4.9          0.2
# 2             4.7          0.2
# 3             4.6          0.2
# 4             5.0          0.2
# ..            ...          ...
# 145           6.7          2.3
# 146           6.3          1.9
# 147           6.5          2.0
# 148           6.2          2.3
# 149           5.9          1.8
#
# [150 rows x 2 columns]

# %%
iris.iloc[20:21,:]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 20           5.4          3.4           1.7          0.2  setosa

# %%
iris.iloc[15:21,[0,3]]
# Out:
#     sepal_length  petal_width
# 15           5.7          0.4
# 16           5.4          0.4
# 17           5.1          0.3
# 18           5.7          0.3
# 19           5.1          0.3
# 20           5.4          0.2

# %%
iris.loc[10:20,'sepal_length':'petal_length']
# Out:
#     sepal_length  sepal_width  petal_length
# 10           5.4          3.7           1.5
# 11           4.8          3.4           1.6
# 12           4.8          3.0           1.4
# 13           4.3          3.0           1.1
# 14           5.8          4.0           1.2
# 15           5.7          4.4           1.5
# 16           5.4          3.9           1.3
# 17           5.1          3.5           1.4
# 18           5.7          3.8           1.7
# 19           5.1          3.8           1.5
# 20           5.4          3.4           1.7

# %%
import pandas as pd
import numpy as np
data={'weight':[66,67,84,96,50,93],'height':[126,127,128,120,170,180]}
bmi=pd.DataFrame(data)
bmi
# Out:
#    weight  height
# 0      66     126
# 1      67     127
# 2      84     128
# 3      96     120
# 4      50     170
# 5      93     180

# %%
#create bmi column
bmi['BMI']=bmi['weight']/(bmi['height']/100)**2
bmi
# Out:
#    weight  height        BMI
# 0      66     126  41.572184
# 1      67     127  41.540083
# 2      84     128  51.269531
# 3      96     120  66.666667
# 4      50     170  17.301038
# 5      93     180  28.703704

# %%
bmi.loc[3]=[78,np.nan,np.nan]
bmi
# Out:
#    weight  height        BMI
# 0      66   126.0  41.572184
# 1      67   127.0  41.540083
# 2      84   128.0  51.269531
# 3      78     NaN        NaN
# 4      50   170.0  17.301038
# 5      93   180.0  28.703704

# %%
bmi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  6 non-null      int64
#  1   height  5 non-null      float64
#  2   BMI     5 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 276.0 bytes

# %%
bmi.isnull().sum()
# Out:
# weight    0
# height    1
# BMI       1
# dtype: int64

# %%
bmi['weight'] =bmi['weight'].fillna(165)
bmi
# Out:
#    weight  height        BMI
# 0      66      66  41.572184
# 1      67      67  41.540083
# 2      84      84  51.269531
# 3      78      78        NaN
# 4      50      50  17.301038
# 5      93      93  28.703704

# %%
bmi['height'] =bmi['height'].fillna(78)
bmi
# Out:
#    weight  height        BMI
# 0      66      66  41.572184
# 1      67      67  41.540083
# 2      84      84  51.269531
# 3      78      78        NaN
# 4      50      50  17.301038
# 5      93      93  28.703704
